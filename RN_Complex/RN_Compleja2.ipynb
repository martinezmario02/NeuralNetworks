# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Load pictures and labels:
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Input, Reshape, UpSampling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

def load_pictures(link):
    with open(link, 'rb') as f:
        f.read(16)
        buffer = f.read()
        pictures = np.frombuffer(buffer, dtype=np.uint8).reshape(-1, 28, 28)
    return pictures

def load_labels(link):
    with open(link, 'rb') as f:
        f.read(8)
        labels = np.frombuffer(f.read(), dtype=np.uint8)
    return labels

train_images = load_pictures('/content/drive/MyDrive/MÁSTER/IC/P1/Train/train-images.idx3-ubyte')
train_labels = load_labels('/content/drive/MyDrive/MÁSTER/IC/P1/Train/train-labels.idx1-ubyte')

evaluation_images = load_pictures('/content/drive/MyDrive/MÁSTER/IC/P1/Evaluation/t10k-images.idx3-ubyte')
evaluation_labels = load_labels('/content/drive/MyDrive/MÁSTER/IC/P1/Evaluation/t10k-labels.idx1-ubyte')

train_images = train_images / 255.0
evaluation_images = evaluation_images / 255.0

train_images = train_images.reshape(-1, 28, 28, 1)
evaluation_images = evaluation_images.reshape(-1, 28, 28, 1)

train_labels = to_categorical(train_labels)
evaluation_labels = to_categorical(evaluation_labels)

datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.2,
    horizontal_flip=False
)
datagen.fit(train_images)

# %%
# Autoencoder
input_img = Input(shape=(28, 28, 1))

x = Conv2D(64, (3, 3), activation='relu', padding='same')(input_img)
x = BatchNormalization()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(128, (3, 3), activation='relu', padding='same')(encoded)
x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
x = BatchNormalization()(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)

autoencoder = Model(input_img, decoded)
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')

# %%
# Training autoencoder
autoencoder.fit(train_images, train_images, epochs=20, batch_size=128, shuffle=True, validation_data=(evaluation_images, evaluation_images))
# Out:
# Epoch 1/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 20s 25ms/step - loss: 0.2190 - val_loss: 0.6857
# Epoch 2/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0687 - val_loss: 0.0659
# Epoch 3/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 0.0663 - val_loss: 0.0654
# Epoch 4/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 12s 16ms/step - loss: 0.0652 - val_loss: 0.0644
# Epoch 5/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 0.0642 - val_loss: 0.0632
# Epoch 6/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 0.0636 - val_loss: 0.0629
# Epoch 7/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - loss: 0.0632 - val_loss: 0.0632
# Epoch 8/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0628 - val_loss: 0.0624
# Epoch 9/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0627 - val_loss: 0.0622
# Epoch 10/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0623 - val_loss: 0.0619
# Epoch 11/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0621 - val_loss: 0.0625
# Epoch 12/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 7s 14ms/step - loss: 0.0619 - val_loss: 0.0618
# Epoch 13/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0619 - val_loss: 0.0621
# Epoch 14/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0619 - val_loss: 0.0612
# Epoch 15/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0616 - val_loss: 0.0614
# Epoch 16/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0615 - val_loss: 0.0623
# Epoch 17/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0614 - val_loss: 0.0617
# Epoch 18/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0613 - val_loss: 0.0609
# Epoch 19/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 11s 15ms/step - loss: 0.0612 - val_loss: 0.0609
# Epoch 20/20
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - loss: 0.0611 - val_loss: 0.0608

# %%
# Neural network:
encoder = Model(input_img, encoded)
encoded_train_images = encoder.predict(train_images)
encoded_evaluation_images = encoder.predict(evaluation_images)

model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Training neural network
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

model.fit(
    datagen.flow(train_images, train_labels, batch_size=128),
    epochs=100,
    validation_data=(evaluation_images, evaluation_labels),
    callbacks=[reduce_lr, early_stopping],
    verbose=1
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 64ms/step - accuracy: 0.7352 - loss: 0.8997 - val_accuracy: 0.8409 - val_loss: 0.4814 - learning_rate: 0.0010
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 30s 53ms/step - accuracy: 0.9541 - loss: 0.1518 - val_accuracy: 0.9893 - val_loss: 0.0300 - learning_rate: 0.0010
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9683 - loss: 0.1052 - val_accuracy: 0.9915 - val_loss: 0.0235 - learning_rate: 0.0010
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 54ms/step - accuracy: 0.9739 - loss: 0.0850 - val_accuracy: 0.9927 - val_loss: 0.0226 - learning_rate: 0.0010
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9776 - loss: 0.0726 - val_accuracy: 0.9931 - val_loss: 0.0216 - learning_rate: 0.0010
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9798 - loss: 0.0654 - val_accuracy: 0.9939 - val_loss: 0.0202 - learning_rate: 0.0010
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 26s 55ms/step - accuracy: 0.9828 - loss: 0.0577 - val_accuracy: 0.9929 - val_loss: 0.0209 - learning_rate: 0.0010
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9827 - loss: 0.0547 - val_accuracy: 0.9941 - val_loss: 0.0182 - learning_rate: 0.0010
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.9854 - loss: 0.0511 - val_accuracy: 0.9931 - val_loss: 0.0195 - learning_rate: 0.0010
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9847 - loss: 0.0506 - val_accuracy: 0.9933 - val_loss: 0.0187 - learning_rate: 0.0010
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9854 - loss: 0.0477 - val_accuracy: 0.9921 - val_loss: 0.0256 - learning_rate: 0.0010
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9860 - loss: 0.0470 - val_accuracy: 0.9951 - val_loss: 0.0154 - learning_rate: 0.0010
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.9880 - loss: 0.0410 - val_accuracy: 0.9946 - val_loss: 0.0148 - learning_rate: 0.0010
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9890 - loss: 0.0367 - val_accuracy: 0.9941 - val_loss: 0.0180 - learning_rate: 0.0010
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9880 - loss: 0.0388 - val_accuracy: 0.9953 - val_loss: 0.0138 - learning_rate: 0.0010
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.9888 - loss: 0.0363 - val_accuracy: 0.9954 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9879 - loss: 0.0380 - val_accuracy: 0.9954 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9898 - loss: 0.0326 - val_accuracy: 0.9955 - val_loss: 0.0142 - learning_rate: 0.0010
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 50ms/step - accuracy: 0.9897 - loss: 0.0331 - val_accuracy: 0.9949 - val_loss: 0.0130 - learning_rate: 0.0010
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9903 - loss: 0.0317 - val_accuracy: 0.9958 - val_loss: 0.0149 - learning_rate: 0.0010
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9903 - loss: 0.0330 - val_accuracy: 0.9953 - val_loss: 0.0143 - learning_rate: 0.0010
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9901 - loss: 0.0327 - val_accuracy: 0.9961 - val_loss: 0.0134 - learning_rate: 0.0010
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9908 - loss: 0.0313 - val_accuracy: 0.9953 - val_loss: 0.0143 - learning_rate: 0.0010
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9900 - loss: 0.0315 - val_accuracy: 0.9953 - val_loss: 0.0139 - learning_rate: 0.0010
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9919 - loss: 0.0273 - val_accuracy: 0.9965 - val_loss: 0.0098 - learning_rate: 2.0000e-04
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 48ms/step - accuracy: 0.9937 - loss: 0.0218 - val_accuracy: 0.9966 - val_loss: 0.0096 - learning_rate: 2.0000e-04
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 26s 56ms/step - accuracy: 0.9927 - loss: 0.0223 - val_accuracy: 0.9965 - val_loss: 0.0097 - learning_rate: 2.0000e-04
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 39s 51ms/step - accuracy: 0.9937 - loss: 0.0218 - val_accuracy: 0.9969 - val_loss: 0.0095 - learning_rate: 2.0000e-04
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9935 - loss: 0.0211 - val_accuracy: 0.9967 - val_loss: 0.0098 - learning_rate: 2.0000e-04
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9943 - loss: 0.0209 - val_accuracy: 0.9969 - val_loss: 0.0090 - learning_rate: 2.0000e-04
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9945 - loss: 0.0178 - val_accuracy: 0.9971 - val_loss: 0.0094 - learning_rate: 2.0000e-04
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9943 - loss: 0.0185 - val_accuracy: 0.9971 - val_loss: 0.0092 - learning_rate: 2.0000e-04
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 51ms/step - accuracy: 0.9936 - loss: 0.0193 - val_accuracy: 0.9970 - val_loss: 0.0088 - learning_rate: 2.0000e-04
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9945 - loss: 0.0195 - val_accuracy: 0.9970 - val_loss: 0.0097 - learning_rate: 2.0000e-04
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9948 - loss: 0.0184 - val_accuracy: 0.9969 - val_loss: 0.0091 - learning_rate: 2.0000e-04
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9947 - loss: 0.0178 - val_accuracy: 0.9963 - val_loss: 0.0106 - learning_rate: 2.0000e-04
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9945 - loss: 0.0181 - val_accuracy: 0.9970 - val_loss: 0.0099 - learning_rate: 2.0000e-04
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9938 - loss: 0.0189 - val_accuracy: 0.9971 - val_loss: 0.0095 - learning_rate: 2.0000e-04
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 48ms/step - accuracy: 0.9948 - loss: 0.0162 - val_accuracy: 0.9969 - val_loss: 0.0092 - learning_rate: 4.0000e-05
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.9948 - loss: 0.0170 - val_accuracy: 0.9967 - val_loss: 0.0093 - learning_rate: 4.0000e-05
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 51ms/step - accuracy: 0.9945 - loss: 0.0179 - val_accuracy: 0.9971 - val_loss: 0.0092 - learning_rate: 4.0000e-05
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 50ms/step - accuracy: 0.9953 - loss: 0.0160 - val_accuracy: 0.9969 - val_loss: 0.0093 - learning_rate: 4.0000e-05
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9948 - loss: 0.0174 - val_accuracy: 0.9968 - val_loss: 0.0093 - learning_rate: 4.0000e-05

# %%
# Train set:
_, train_accuracy = model.evaluate(train_images, train_labels, verbose=0)
print(f"Train Accuracy: {train_accuracy * 100:.2f}%")

# Evaluate set:
_, evaluation_accuracy = model.evaluate(evaluation_images, evaluation_labels, verbose=0)
print(f"Evaluation Accuracy: {evaluation_accuracy * 100:.2f}%")
# Out:
# Train Accuracy: 99.84%
# Evaluation Accuracy: 99.70%

# %%
evaluation_labels = np.argmax(evaluation_labels, axis=1)
sequence_result = ''.join(map(str, evaluation_labels))

print("Secuencia de etiquetas del conjunto de prueba:")
print(sequence_result)
# Out:
# Secuencia de etiquetas del conjunto de prueba:
# ...
