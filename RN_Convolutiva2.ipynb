# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Load pictures and labels:
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

def load_pictures(link):
    with open(link, 'rb') as f:
        f.read(16)
        buffer = f.read()
        pictures = np.frombuffer(buffer, dtype=np.uint8).reshape(-1, 28, 28)
    return pictures

def load_labels(link):
    with open(link, 'rb') as f:
        f.read(8)
        labels = np.frombuffer(f.read(), dtype=np.uint8)
    return labels

train_images = load_pictures('/content/drive/MyDrive/MÁSTER/IC/P1/Train/train-images.idx3-ubyte')
train_labels = load_labels('/content/drive/MyDrive/MÁSTER/IC/P1/Train/train-labels.idx1-ubyte')

evaluation_images = load_pictures('/content/drive/MyDrive/MÁSTER/IC/P1/Evaluation/t10k-images.idx3-ubyte')
evaluation_labels = load_labels('/content/drive/MyDrive/MÁSTER/IC/P1/Evaluation/t10k-labels.idx1-ubyte')

train_images = train_images / 255.0
evaluation_images = evaluation_images / 255.0

train_images = train_images.reshape(-1, 28, 28, 1)
evaluation_images = evaluation_images.reshape(-1, 28, 28, 1)

# %%
# Neural network:
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

train_labels = to_categorical(train_labels)
evaluation_labels = to_categorical(evaluation_labels)

datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1
)
datagen.fit(train_images)

model = Sequential([
    Conv2D(64, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.3),

    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(128, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.4),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6) # Reajustar learning_rate si lleva 3 etapas sin mejorar

model.fit(
    datagen.flow(train_images, train_labels, batch_size=64),
    epochs=50,
    validation_data=(evaluation_images, evaluation_labels),
    callbacks=[reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - accuracy: 0.9915 - loss: 0.0272 - val_accuracy: 0.9962 - val_loss: 0.0105 - learning_rate: 6.2500e-06
# Epoch 2/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 27ms/step - accuracy: 0.9918 - loss: 0.0282 - val_accuracy: 0.9958 - val_loss: 0.0107 - learning_rate: 6.2500e-06
# Epoch 3/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 42s 28ms/step - accuracy: 0.9914 - loss: 0.0272 - val_accuracy: 0.9955 - val_loss: 0.0105 - learning_rate: 6.2500e-06
# Epoch 4/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - accuracy: 0.9914 - loss: 0.0283 - val_accuracy: 0.9956 - val_loss: 0.0112 - learning_rate: 6.2500e-06
# Epoch 5/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - accuracy: 0.9917 - loss: 0.0270 - val_accuracy: 0.9957 - val_loss: 0.0110 - learning_rate: 3.1250e-06
# Epoch 6/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.9923 - loss: 0.0265 - val_accuracy: 0.9956 - val_loss: 0.0108 - learning_rate: 3.1250e-06
# Epoch 7/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 27s 28ms/step - accuracy: 0.9914 - loss: 0.0285 - val_accuracy: 0.9959 - val_loss: 0.0108 - learning_rate: 3.1250e-06
# Epoch 8/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 28ms/step - accuracy: 0.9913 - loss: 0.0281 - val_accuracy: 0.9958 - val_loss: 0.0106 - learning_rate: 1.5625e-06
# Epoch 9/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9926 - loss: 0.0255 - val_accuracy: 0.9958 - val_loss: 0.0107 - learning_rate: 1.5625e-06
# Epoch 10/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 25s 27ms/step - accuracy: 0.9922 - loss: 0.0256 - val_accuracy: 0.9959 - val_loss: 0.0107 - learning_rate: 1.5625e-06
# Epoch 11/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 27ms/step - accuracy: 0.9922 - loss: 0.0261 - val_accuracy: 0.9958 - val_loss: 0.0107 - learning_rate: 1.0000e-06
# Epoch 12/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9921 - loss: 0.0245 - val_accuracy: 0.9959 - val_loss: 0.0106 - learning_rate: 1.0000e-06
# Epoch 13/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 27ms/step - accuracy: 0.9918 - loss: 0.0257 - val_accuracy: 0.9958 - val_loss: 0.0106 - learning_rate: 1.0000e-06
# Epoch 14/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 26ms/step - accuracy: 0.9917 - loss: 0.0262 - val_accuracy: 0.9956 - val_loss: 0.0108 - learning_rate: 1.0000e-06
# Epoch 15/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9919 - loss: 0.0260 - val_accuracy: 0.9958 - val_loss: 0.0105 - learning_rate: 1.0000e-06
# Epoch 16/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 40s 27ms/step - accuracy: 0.9916 - loss: 0.0270 - val_accuracy: 0.9956 - val_loss: 0.0106 - learning_rate: 1.0000e-06
# Epoch 17/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - accuracy: 0.
# Epoch 50/50
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 26s 28ms/step - accuracy: 0.9918 - loss: 0.0269 - val_accuracy: 0.9959 - val_loss: 0.0107 - learning_rate: 1.0000e-06

# %%
# Train set :
_, train_accuracy = model.evaluate(train_images, train_labels, verbose=0)
print(f"Train Accuracy: {train_accuracy * 100:.2f}%")

# Evaluate set:
_, evaluation_accuracy = model.evaluate(evaluation_images, evaluation_labels, verbose=0)
print(f"Evaluation Accuracy: {evaluation_accuracy * 100:.2f}%")
# Out:
# Train Accuracy: 99.77%
# Evaluation Accuracy: 99.59%

# %%
from google.colab import drive
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import to_categorical

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)

# Load pictures and labels (no changes needed here)
def load_pictures(link):
    with open(link, 'rb') as f:
        f.read(16)
        buffer = f.read()
        pictures = np.frombuffer(buffer, dtype=np.uint8).reshape(-1, 28, 28)
    return pictures

def load_labels(link):
    with open(link, 'rb') as f:
        f.read(8)
        labels = np.frombuffer(f.read(), dtype=np.uint8)
    return labels

train_images = load_pictures('/content/drive/MyDrive/MÁSTER/IC/P1/Train/train-images.idx3-ubyte')
train_labels = load_labels('/content/drive/MyDrive/MÁSTER/IC/P1/Train/train-labels.idx1-ubyte')

evaluation_images = load_pictures('/content/drive/MyDrive/MÁSTER/IC/P1/Evaluation/t10k-images.idx3-ubyte')
evaluation_labels = load_labels('/content/drive/MyDrive/MÁSTER/IC/P1/Evaluation/t10k-labels.idx1-ubyte')

train_images = train_images / 255.0
evaluation_images = evaluation_images / 255.0

train_images = train_images.reshape(-1, 28, 28, 1)
evaluation_images = evaluation_images.reshape(-1, 28, 28, 1)

train_labels = to_categorical(train_labels)
evaluation_labels = to_categorical(evaluation_labels)

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    shear_range=0.2, # Added shear_range for more diverse transformations
    horizontal_flip=False # Consider horizontal_flip if applicable to your data
)
datagen.fit(train_images)


# Model definition with adjustments
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    BatchNormalization(),
    Conv2D(32, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25), # Reduced initial dropout

    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    Conv2D(64, (3, 3), activation='relu'),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25), # Reduced dropout

    Flatten(),
    Dense(128, activation='relu'), # Reduced dense layer size
    BatchNormalization(),
    Dropout(0.5), #Kept higher dropout for the dense layer
    Dense(10, activation='softmax')
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

#Callbacks
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-6)
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True) #Early stopping


# Training
history = model.fit(
    datagen.flow(train_images, train_labels, batch_size=128), # Increased batch size
    epochs=100, # Increased epochs, early stopping will prevent overfitting
    validation_data=(evaluation_images, evaluation_labels),
    callbacks=[reduce_lr, early_stopping], #Added early stopping
    verbose=1
)


# Evaluate the model
_, train_accuracy = model.evaluate(train_images, train_labels, verbose=0)
print(f"Train Accuracy: {train_accuracy * 100:.2f}%")

_, evaluation_accuracy = model.evaluate(evaluation_images, evaluation_labels, verbose=0)
print(f"Evaluation Accuracy: {evaluation_accuracy * 100:.2f}%")
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 47s 73ms/step - accuracy: 0.7370 - loss: 0.8653 - val_accuracy: 0.8496 - val_loss: 0.4590 - learning_rate: 0.0010
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 63s 51ms/step - accuracy: 0.9574 - loss: 0.1377 - val_accuracy: 0.9918 - val_loss: 0.0246 - learning_rate: 0.0010
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9692 - loss: 0.0999 - val_accuracy: 0.9933 - val_loss: 0.0212 - learning_rate: 0.0010
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9755 - loss: 0.0817 - val_accuracy: 0.9914 - val_loss: 0.0267 - learning_rate: 0.0010
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9788 - loss: 0.0717 - val_accuracy: 0.9897 - val_loss: 0.0309 - learning_rate: 0.0010
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9796 - loss: 0.0642 - val_accuracy: 0.9921 - val_loss: 0.0239 - learning_rate: 0.0010
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.9827 - loss: 0.0571 - val_accuracy: 0.9939 - val_loss: 0.0171 - learning_rate: 0.0010
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9846 - loss: 0.0520 - val_accuracy: 0.9943 - val_loss: 0.0179 - learning_rate: 0.0010
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 52ms/step - accuracy: 0.9855 - loss: 0.0483 - val_accuracy: 0.9953 - val_loss: 0.0144 - learning_rate: 0.0010
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9867 - loss: 0.0449 - val_accuracy: 0.9943 - val_loss: 0.0184 - learning_rate: 0.0010
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9867 - loss: 0.0431 - val_accuracy: 0.9949 - val_loss: 0.0162 - learning_rate: 0.0010
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.9862 - loss: 0.0449 - val_accuracy: 0.9945 - val_loss: 0.0159 - learning_rate: 0.0010
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9881 - loss: 0.0414 - val_accuracy: 0.9953 - val_loss: 0.0140 - learning_rate: 0.0010
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9888 - loss: 0.0374 - val_accuracy: 0.9932 - val_loss: 0.0244 - learning_rate: 0.0010
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9870 - loss: 0.0437 - val_accuracy: 0.9931 - val_loss: 0.0200 - learning_rate: 0.0010
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 52ms/step - accuracy: 0.9871 - loss: 0.0413 - val_accuracy: 0.9950 - val_loss: 0.0172 - learning_rate: 0.0010
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9889 - loss: 0.0380 - val_accuracy: 0.9946 - val_loss: 0.0160 - learning_rate: 0.0010
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9901 - loss: 0.0354 - val_accuracy: 0.9945 - val_loss: 0.0164 - learning_rate: 0.0010
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 52ms/step - accuracy: 0.9913 - loss: 0.0284 - val_accuracy: 0.9958 - val_loss: 0.0123 - learning_rate: 2.0000e-04
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9919 - loss: 0.0268 - val_accuracy: 0.9964 - val_loss: 0.0116 - learning_rate: 2.0000e-04
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9919 - loss: 0.0253 - val_accuracy: 0.9954 - val_loss: 0.0139 - learning_rate: 2.0000e-04
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 51ms/step - accuracy: 0.9921 - loss: 0.0253 - val_accuracy: 0.9964 - val_loss: 0.0124 - learning_rate: 2.0000e-04
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9928 - loss: 0.0230 - val_accuracy: 0.9967 - val_loss: 0.0105 - learning_rate: 2.0000e-04
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9928 - loss: 0.0241 - val_accuracy: 0.9958 - val_loss: 0.0129 - learning_rate: 2.0000e-04
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9927 - loss: 0.0246 - val_accuracy: 0.9960 - val_loss: 0.0126 - learning_rate: 2.0000e-04
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 27s 56ms/step - accuracy: 0.9929 - loss: 0.0223 - val_accuracy: 0.9956 - val_loss: 0.0146 - learning_rate: 2.0000e-04
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 24s 50ms/step - accuracy: 0.9927 - loss: 0.0239 - val_accuracy: 0.9960 - val_loss: 0.0119 - learning_rate: 2.0000e-04
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 25s 53ms/step - accuracy: 0.9931 - loss: 0.0214 - val_accuracy: 0.9960 - val_loss: 0.0115 - learning_rate: 2.0000e-04
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9931 - loss: 0.0222 - val_accuracy: 0.9962 - val_loss: 0.0113 - learning_rate: 4.0000e-05
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - accuracy: 0.9938 - loss: 0.0219 - val_accuracy: 0.9962 - val_loss: 0.0111 - learning_rate: 4.0000e-05
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9937 - loss: 0.0199 - val_accuracy: 0.9963 - val_loss: 0.0115 - learning_rate: 4.0000e-05
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 40s 49ms/step - accuracy: 0.9941 - loss: 0.0199 - val_accuracy: 0.9965 - val_loss: 0.0111 - learning_rate: 4.0000e-05
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 43s 53ms/step - accuracy: 0.9939 - loss: 0.0189 - val_accuracy: 0.9963 - val_loss: 0.0114 - learning_rate: 4.0000e-05
# Train Accuracy: 99.77%
# Evaluation Accuracy: 99.67%
